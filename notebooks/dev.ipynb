# %%
import sys
sys.path.append("/Users/fgu/dev/projects/ons")

import pandas as pd
import s3fs

import ons.config as c
import ons.helpers as h
import ons.lookup_table as lt

# %load_ext autoreload
# %autoreload 2

fs = s3fs.S3FileSystem(profile=c.AWS_PROFILE)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fs.ls('3di-data-ons/nspl/NSPL_AUG_2020_UK/clean')
# Out:
# ['3di-data-ons/nspl/NSPL_AUG_2020_UK/clean/',
#  '3di-data-ons/nspl/NSPL_AUG_2020_UK/clean/lookup_nspl_aug_2020_uk.parquet']

# %%
lt.main(nrows=10000)
# Out:
# s3://3di-data-ons/nspl/NSPL_AUG_2020_UK/clean/lookup.csv (of shape (24, 5)) written.
#    pcsector region_code region_name rural_urban_code       rural_urban_name
# 0    AB10 1   S99999999    Scotland                1       Large Urban Area
# 1    AB10 6   S99999999    Scotland                1       Large Urban Area
# 2    AB10 7   S99999999    Scotland                1       Large Urban Area
# 3    AB11 5   S99999999    Scotland                1       Large Urban Area
# 4    AB11 6   S99999999    Scotland                1       Large Urban Area
# 5    AB11 7   S99999999    Scotland                1       Large Urban Area
# 6    AB11 8   S99999999    Scotland                1       Large Urban Area
# 7    AB11 9   S99999999    Scotland                1       Large Urban Area
# 8    AB12 3   S99999999    Scotland                1       Large Urban Area
# 9    AB12 4   S99999999    Scotland                6       Accessible Rural
# 10   AB12 5   S99999999    Scotland                1       Large Urban Area
# 11   AB12 9   S99999999    Scotland                1       Large Urban Area
# 12   AB13 0   S99999999    Scotland                3  Accessible Small Town
# 13   AB14 0   S99999999    Scotland                6       Accessible Rural
# 14   AB15 4   S99999999    Scotland                1       Large Urban Area
# 15   AB15 5   S99999999    Scotland                1       Large Urban Area
# 16   AB15 6   S99999999    Scotland                1       Large Urban Area
# 17   AB15 7   S99999999    Scotland                6       Accessible Rural
# 18   AB15 8   S99999999    Scotland                1       Large Urban Area
# 19   AB15 9   S99999999    Scotland                1       Large Urban Area
# 20   AB16 5   S99999999    Scotland                1       Large Urban Area
# 21   AB16 6   S99999999    Scotland                1       Large Urban Area
# 22   AB16 7   S99999999    Scotland                1       Large Urban Area
# 23   AB16 9   S99999999    Scotland                1       Large Urban Area

# %%
h.read_csv('s3://3di-data-ons/nspl/NSPL_AUG_2020_UK/clean/lookup.csv', nrows=10)
# Out:
#   pcsector region_code region_name  rural_urban_code  rural_urban_name
# 0   AB10 1   S99999999    Scotland                 1  Large Urban Area
# 1   AB10 6   S99999999    Scotland                 1  Large Urban Area
# 2   AB10 7   S99999999    Scotland                 1  Large Urban Area
# 3   AB11 5   S99999999    Scotland                 1  Large Urban Area
# 4   AB11 6   S99999999    Scotland                 1  Large Urban Area
# 5   AB11 7   S99999999    Scotland                 1  Large Urban Area
# 6   AB11 8   S99999999    Scotland                 1  Large Urban Area
# 7   AB11 9   S99999999    Scotland                 1  Large Urban Area
# 8   AB12 3   S99999999    Scotland                 1  Large Urban Area
# 9   AB12 4   S99999999    Scotland                 6  Accessible Rural
